# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimasta22/dataSci_plot/blob/main/stock_profitability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
URL = "https://goit.global/textbooks/python/data-science-xf8b2g/v1/docs/module-03/hw"
data = contacts = pd.DataFrame(
    {
        "Доходность A, %": [25, -10, 10, 5, 35, 13],
        "Доходность B, %": [0, 15, -5, 5, 20, 25],
        "Доходность C, %": [10, 25, -15, -5, -5, 15],
    },
    index=[1, 2, 3, 4, 5, 6],
)

# %%
sns.regplot(data['Доходность A, %'], data['Доходность B, %']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(data['Доходность C, %'], data['Доходность B, %']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(data['Доходность A, %'], data['Доходность C, %']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
